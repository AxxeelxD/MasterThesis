# %%
! pip install rdkit pysmiles prettytable pybel huggingface_hub ijson datasets
# Out:
# Requirement already satisfied: rdkit in /opt/conda/lib/python3.11/site-packages (2024.9.6)
# Requirement already satisfied: pysmiles in /opt/conda/lib/python3.11/site-packages (2.0.0)
# Requirement already satisfied: prettytable in /opt/conda/lib/python3.11/site-packages (3.15.1)
# Requirement already satisfied: pybel in /opt/conda/lib/python3.11/site-packages (0.15.5)
# Requirement already satisfied: huggingface_hub in /opt/conda/lib/python3.11/site-packages (0.29.3)
# Requirement already satisfied: ijson in /opt/conda/lib/python3.11/site-packages (3.3.0)
# Requirement already satisfied: datasets in /opt/conda/lib/python3.11/site-packages (3.4.1)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.11/site-packages (from rdkit) (1.26.4)
# Requirement already satisfied: Pillow in /opt/conda/lib/python3.11/site-packages (from rdkit) (10.4.0)
# Requirement already satisfied: pbr in /opt/conda/lib/python3.11/site-packages (from pysmiles) (6.1.1)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.11/site-packages (from pysmiles) (3.3)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.11/site-packages (from prettytable) (0.2.13)
# Requirement already satisfied: sqlalchemy in /opt/conda/lib/python3.11/site-packages (from pybel) (2.0.32)
# Requirement already satisfied: click in /opt/conda/lib/python3.11/site-packages (from pybel) (8.1.7)
# Requirement already satisfied: click-plugins in /opt/conda/lib/python3.11/site-packages (from pybel) (1.1.1)
# Requirement already satisfied: bel-resources>=0.0.3 in /opt/conda/lib/python3.11/site-packages (from pybel) (0.0.3)
# Requirement already satisfied: more-itertools in /opt/conda/lib/python3.11/site-packages (from pybel) (10.6.0)
# Requirement already satisfied: requests in /opt/conda/lib/python3.11/site-packages (from pybel) (2.32.3)
# Requirement already satisfied: requests-file in /opt/conda/lib/python3.11/site-packages (from pybel) (2.1.0)
# Requirement already satisfied: pyparsing in /opt/conda/lib/python3.11/site-packages (from pybel) (3.1.4)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.11/site-packages (from pybel) (4.66.5)
# Requirement already satisfied: humanize in /opt/conda/lib/python3.11/site-packages (from pybel) (4.12.1)
# Requirement already satisfied: tabulate in /opt/conda/lib/python3.11/site-packages (from pybel) (0.9.0)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.11/site-packages (from pybel) (2.1.4)
# Requirement already satisfied: jsonschema in /opt/conda/lib/python3.11/site-packages (from pybel) (4.23.0)
# Requirement already satisfied: bioregistry in /opt/conda/lib/python3.11/site-packages (from pybel) (0.12.7)
# Requirement already satisfied: ratelimit in /opt/conda/lib/python3.11/site-packages (from pybel) (2.2.1)
# Requirement already satisfied: pystow>=0.1.2 in /opt/conda/lib/python3.11/site-packages (from pybel) (0.7.0)
# Requirement already satisfied: psycopg2-binary in /opt/conda/lib/python3.11/site-packages (from pybel) (2.9.10)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.11/site-packages (from huggingface_hub) (3.15.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.11/site-packages (from huggingface_hub) (2024.6.1)
# Requirement already satisfied: packaging>=20.9 in /opt/conda/lib/python3.11/site-packages (from huggingface_hub) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.11/site-packages (from huggingface_hub) (6.0.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.11/site-packages (from huggingface_hub) (4.12.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /opt/conda/lib/python3.11/site-packages (from datasets) (17.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /opt/conda/lib/python3.11/site-packages (from datasets) (0.3.8)
# Requirement already satisfied: xxhash in /opt/conda/lib/python3.11/site-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /opt/conda/lib/python3.11/site-packages (from datasets) (0.70.16)
# Requirement already satisfied: aiohttp in /opt/conda/lib/python3.11/site-packages (from datasets) (3.10.5)
# Requirement already satisfied: multisplitby in /opt/conda/lib/python3.11/site-packages (from bel-resources>=0.0.3->pybel) (0.0.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /opt/conda/lib/python3.11/site-packages (from aiohttp->datasets) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.11/site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.11/site-packages (from aiohttp->datasets) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.11/site-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.11/site-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.11/site-packages (from aiohttp->datasets) (1.9.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests->pybel) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests->pybel) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests->pybel) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests->pybel) (2024.8.30)
# Requirement already satisfied: more_click>=0.1.2 in /opt/conda/lib/python3.11/site-packages (from bioregistry->pybel) (0.1.2)
# Requirement already satisfied: pydantic>=2.0 in /opt/conda/lib/python3.11/site-packages (from pydantic[email]>=2.0->bioregistry->pybel) (2.8.2)
# Requirement already satisfied: curies>=0.7.0 in /opt/conda/lib/python3.11/site-packages (from bioregistry->pybel) (0.10.10)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/conda/lib/python3.11/site-packages (from jsonschema->pybel) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/conda/lib/python3.11/site-packages (from jsonschema->pybel) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/conda/lib/python3.11/site-packages (from jsonschema->pybel) (0.20.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.11/site-packages (from pandas->pybel) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.11/site-packages (from pandas->pybel) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.11/site-packages (from pandas->pybel) (2024.1)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.11/site-packages (from pbr->pysmiles) (72.2.0)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/lib/python3.11/site-packages (from sqlalchemy->pybel) (3.0.3)
# Requirement already satisfied: pytrie in /opt/conda/lib/python3.11/site-packages (from curies>=0.7.0->bioregistry->pybel) (0.4.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/conda/lib/python3.11/site-packages (from pydantic>=2.0->pydantic[email]>=2.0->bioregistry->pybel) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /opt/conda/lib/python3.11/site-packages (from pydantic>=2.0->pydantic[email]>=2.0->bioregistry->pybel) (2.20.1)
# Requirement already satisfied: email-validator>=2.0.0 in /opt/conda/lib/python3.11/site-packages (from pydantic[email]>=2.0->bioregistry->pybel) (2.2.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->pybel) (1.16.0)
# Requirement already satisfied: dnspython>=2.0.0 in /opt/conda/lib/python3.11/site-packages (from email-validator>=2.0.0->pydantic[email]>=2.0->bioregistry->pybel) (2.7.0)
# Requirement already satisfied: sortedcontainers in /opt/conda/lib/python3.11/site-packages (from pytrie->curies>=0.7.0->bioregistry->pybel) (2.4.0)

# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from torch.utils.data import TensorDataset, DataLoader
from prettytable import PrettyTable
import multiprocessing
from scipy import stats
import os, sys
import time
import json

# %%
start = time.time()

file_dir = os.path.dirname("../")
sys.path.append(file_dir)

from anima.smiles import SMILES

sml = SMILES()

cores = int(multiprocessing.cpu_count())
print(f"Cores: {cores}, GPUs: {torch.cuda.device_count()}")

# Checking CUDA
torch.cuda.empty_cache()
use_cuda = True
print(f"Cuda available: {torch.cuda.is_available()}")
device = torch.device(
    "cuda" if (use_cuda and torch.cuda.is_available()) else "cpu")
# Out:
# Cores: 24, GPUs: 1
# Cuda available: True

# %%
database = pd.read_csv("../anima-master/databases/OMEAD_41801.csv")

print(f"\nDatabase shape: {database.shape}\n")

train_db = database
train_db["homo_lumo_gap"] = train_db.lumo - train_db.homo
smiles = np.array(train_db.smiles)
#train_db.to_csv("changed_test200k.csv")
print(f"\nNew size of train database: {train_db.shape}\n")


# Define SMILES vocabulary

print("\nDefining SMILES vocabulary\n")
vocab = sml.smilesVOC(smiles, n_jobs=cores)

vocab_size = len(vocab)

print(f"\nSize of vocabulary: {vocab_size}\n")

# Saving the vocabulary
with open('vocab.dat', 'w') as f:
    for i in vocab:
        f.write(str(i) + '\n')
    f.close()
# Out:
# Database shape: (41801, 20)
#
#
# New size of train database: (41801, 21)
#
#
# Defining SMILES vocabulary
# [Parallel(n_jobs=24)]: Using backend ThreadingBackend with 24 concurrent workers.
# [Parallel(n_jobs=24)]: Done   2 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=24)]: Done 152 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=24)]: Done 402 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=24)]: Done 752 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=24)]: Done 1202 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=24)]: Done 1752 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=24)]: Done 2402 tasks      | elapsed:    3.8s
# [Parallel(n_jobs=24)]: Done 3152 tasks      | elapsed:    6.3s
# [Parallel(n_jobs=24)]: Done 4002 tasks      | elapsed:    9.1s
# [Parallel(n_jobs=24)]: Done 4952 tasks      | elapsed:   12.2s
# [Parallel(n_jobs=24)]: Done 6002 tasks      | elapsed:   15.8s
# [Parallel(n_jobs=24)]: Done 7152 tasks      | elapsed:   19.8s
# [Parallel(n_jobs=24)]: Done 8402 tasks      | elapsed:   24.0s
# [Parallel(n_jobs=24)]: Done 9752 tasks      | elapsed:   28.7s
# [Parallel(n_jobs=24)]: Done 11202 tasks      | elapsed:   33.7s
# [Parallel(n_jobs=24)]: Done 12752 tasks      | elapsed:   38.9s
# [Parallel(n_jobs=24)]: Done 14402 tasks      | elapsed:   44.8s
# [Parallel(n_jobs=24)]: Done 16152 tasks      | elapsed:   51.2s
# [Parallel(n_jobs=24)]: Done 18002 tasks      | elapsed:   57.5s
# [Parallel(n_jobs=24)]: Done 19952 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=24)]: Done 22002 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=24)]: Done 24152 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=24)]: Done 26402 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=24)]: Done 28752 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=24)]: Done 31202 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=24)]: Done 33752 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=24)]: Done 36402 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=24)]: Done 39152 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=24)]: Done 41801 out of 41801 | elapsed:  2.3min finished
# Size of vocabulary: 33

# %%
# Preparing SMILES into SEQUENCES or 1h tensors
# for embeddings
all_sequences = []

l = 1
for i in smiles:
    print(l, end="\r")
    all_sequences.append(torch.tensor(sml.smilesToSequence(i, vocab)))
    l += 1

# for embeddings
packing = torch.nn.utils.rnn.pack_sequence(
    all_sequences,
    enforce_sorted = False
)

packing_padding = torch.nn.utils.rnn.pad_packed_sequence(
    packing,
    batch_first = True
)


# Check dimensions
# for embedding
# BATCH x SEQUENCE x INFO
print(f"\nCheck packing shape: {packing_padding[0][:,:,:].size()}\n")


temp = packing_padding[0][:,:,0]
random_state = 1
test_size = 0.12

# inputs
x_train, x_test = train_test_split(
    temp.numpy(),
    test_size=test_size,
    random_state=1
)
del temp

gap = np.array(train_db.homo_lumo_gap)
# targets / outputs
y_train, y_test = train_test_split(
    gap,
    test_size=test_size,
    random_state=1
)

max_length = x_train.shape[-1]
# Store max length for prediction model
config = {"max_length": max_length}

with open('config.json', 'w') as f:
    json.dump(config, f)
    f.close()


# max length of tensor sequences
print(f"\nMax length of tensor sequences: {x_train.shape[-1]}")

print(f"\nTest size: {x_test.shape}\n")
print(f"\nTrain size: {x_train.shape}\n")
# Out:
# 41801
# Check packing shape: torch.Size([41801, 224, 1])
#
#
# Max length of tensor sequences: 224
#
# Test size: (5017, 224)
#
#
# Train size: (36784, 224)

# %%
# Define TOOLS
def model_evaluation(model, x_test, y_test, device):
    batch_size=64

    test_data = TensorDataset(
        torch.tensor(x_test),
        torch.tensor(y_test)
    )

    test_loader = DataLoader(
        test_data,
        shuffle= False,
        batch_size= batch_size,
        drop_last = False
    )

    running_mae = []
    running_mse = []
    mae = torch.nn.L1Loss().to(device)
    mse = torch.nn.SmoothL1Loss().to(device)

    model.eval().to(device)

    with torch.no_grad():
        for batch_idx, data in enumerate(test_loader):
            inputs, targets = data
            inputs, targets = inputs.to(device), targets.to(device)
            targets = targets.double()

            output = model(inputs)

            loss_mae = mae(output, targets)
            loss_mse = mse(output, targets)

            running_mae.append(loss_mae.item())
            running_mse.append(loss_mse.item())

    model.train()
    return np.mean(running_mae), np.mean(running_mse)


def model_predictions(model, x, device, batch_size = 64):
    # predictions

    model.eval().to(device)

    pred_data = TensorDataset(torch.tensor(x))
    pred_loader = DataLoader(
        pred_data,
        shuffle=False,
        batch_size=batch_size,
        drop_last=False,
    )

    batches = len(x) / batch_size

    with torch.no_grad():
        for batch_idx, data in enumerate(pred_loader):
            print(f"Batch: {batch_idx + 1:010.2f} of {batches:010.2f}", end="\r")
            inputs = data[0]
            inputs = inputs.to(device)

            output = model(inputs)
            if batch_idx == 0:
                temp = output.cpu().detach().numpy()
            else:
                temp = np.append(temp, output.cpu().detach().numpy())
            del inputs, output

    return np.reshape(temp, -1)

# %%
class SMILESTransformerRegressor(nn.Module):
    def __init__(self, vocab_size, embed_dim, n_heads, n_layers, hidden_dim, max_len, output_dim, dropout):
        super(SMILESTransformerRegressor, self).__init__()

        self.embeddings = nn.Embedding(vocab_size + 1, embed_dim, padding_idx=0)

        # Positional encoding
        self.positional_encoding = nn.Parameter(torch.randn(1, max_len, embed_dim))

        # Dropout
        self.dropout = nn.Dropout(dropout)

        # Transformer encoding
        encoder_layer = nn.TransformerEncoderLayer(
                d_model=embed_dim,
                nhead=n_heads,
                dim_feedforward=hidden_dim,
                batch_first=True
                )

        self.transformer_encoder = nn.TransformerEncoder(
                encoder_layer,
                num_layers=n_layers)

        # Regression head
        self.fc = nn.Sequential(
                nn.Linear(embed_dim, hidden_dim),
                nn.ReLU(),
                nn.Linear(hidden_dim, output_dim)
                )

    def forward(self, x):
         """
         x: Tensor of shape (batch_size, seq_len)
         """
         batch_size, seq_len = x.shape

         # Embed and add positional encoding
         x_embed = self.embeddings(x) # (batch size, seq_len, embed_dim)

         # If sequence is shorter than max_len, crop pos encoding
         pos_enc = self.positional_encoding[:, :seq_len, :].to(x.device) # (1, seq_len, embed_dim)
         x_embed = x_embed + pos_enc

         # Transformer expects input shape (batch_size, seq_len, embed_dim)
         x_transformed = self.transformer_encoder(x_embed)

         # Pooling: mean over sequence dimension
         x_pooled = x_transformed.mean(dim=1) # (batch_size, embed_dim)

         out = self.fc(x_pooled) # (batch_size, 1)
         return out.squeeze(1) # (batch_size, )

# %%
epochs = 2000
all_data = len(x_train)
log = 10

# Read best params from evo algorithm
with open('best_param.json', 'r') as f:
    best_params = json.load(f)
    f.close()

embed_dim = best_params["embed_dim"]
n_heads = best_params["n_heads"]
n_layers = best_params["n_layers"]
hidden_dim = best_params["hidden_dim"]
output_dim = 1
weight_decay = best_params["weight_decay"]
batch_size = best_params["batch_size"]
dropout = best_params["dropout"]

#embed_dim = 128
#n_heads = 4
#n_layers = 2
#hidden_dim = 256
#output_dim = 1
#weight_decay = 1e-5
#batch_size = 64

nn_gap = SMILESTransformerRegressor(vocab_size, embed_dim, n_heads, n_layers, hidden_dim, max_length, output_dim, dropout)
nn_gap.float().to(device)

# loss
metric = torch.nn.SmoothL1Loss().double()
optimizer = torch.optim.Adam(nn_gap.parameters(), lr=0.001, weight_decay=weight_decay)

# setting the dataloader
train_data = TensorDataset(torch.tensor(x_train), torch.tensor(y_train))
train_loader = DataLoader(train_data, shuffle=True, batch_size=batch_size, drop_last=False, pin_memory=True)


epoch_loss = []
test_loss = []

for epoch in range(epochs):
    nn_gap.train().to(device)
    
    running_loss = []
    running_metric = []
    for batch_idx, data in enumerate(train_loader):
        # get the inputs; data is a list of [inputs, labels]
        inputs = data[0]
        targets = data[1]
        inputs, targets = inputs.to(device), targets.to(device)
        targets = targets.double()

        optimizer.zero_grad()

        output = nn_gap(inputs)

        loss = torch.mean(torch.abs(targets - output))
        loss.backward()
        optimizer.step()

        # Print statistics every log
        running_loss.append(loss.item())
        running_metric.append(metric(output, targets).item())
        if batch_idx % log == 0:
            print(f"Epoch {epoch+1:04d} [{batch_idx * len(inputs):05d}/{all_data:05d} ({100 * batch_idx * batch_size / len(train_data):04.1f})%] \t\t Loss: {np.mean(running_loss):02.3f}", end="\r")

    epoch_loss.append(np.mean(running_loss))
    test_mae, test_mse = model_evaluation(nn_gap, x_test, y_test, device)
    test_loss.append(test_mae)

    print(f"Epoch: {epoch + 1:04d} [] Train (Loss={np.mean(running_loss):02.3f} | Metric={np.mean(running_metric):02.3f})\tVal. (MAE={test_mae:02.3f} | HL={test_mse:02.3f})", end="\n")

print("\n")
print(f"\n Train Loss: {round(epoch_loss[-1], 2)}")
print(f"\n Test MAE: {round(test_loss[-1], 2)}")
print("\n Finished training")
# Out:
# Epoch: 0001 [] Train (Loss=0.033 | Metric=0.003)	Val. (MAE=0.018 | HL=0.000)
# Epoch: 0002 [] Train (Loss=0.018 | Metric=0.000)	Val. (MAE=0.023 | HL=0.000)
# Epoch: 0003 [] Train (Loss=0.018 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 0004 [] Train (Loss=0.017 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0005 [] Train (Loss=0.017 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0006 [] Train (Loss=0.017 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 0007 [] Train (Loss=0.017 | Metric=0.000)	Val. (MAE=0.018 | HL=0.000)
# Epoch: 0008 [] Train (Loss=0.017 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0009 [] Train (Loss=0.017 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0010 [] Train (Loss=0.016 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0011 [] Train (Loss=0.016 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0012 [] Train (Loss=0.016 | Metric=0.000)	Val. (MAE=0.019 | HL=0.000)
# Epoch: 0013 [] Train (Loss=0.016 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0014 [] Train (Loss=0.016 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0015 [] Train (Loss=0.016 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0016 [] Train (Loss=0.016 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 0017 [] Train (Loss=0.016 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0018 [] Train (Loss=0.016 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0019 [] Train (Loss=0.016 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0020 [] Train (Loss=0.016 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0021 [] Train (Loss=0.016 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 0022 [] Train (Loss=0.016 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0023 [] Train (Loss=0.016 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0024 [] Train (Loss=0.016 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0025 [] Train (Loss=0.016 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0026 [] Train (Loss=0.016 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 0027 [] Train (Loss=0.016 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0028 [] Train (Loss=0.016 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0029 [] Train (Loss=0.016 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0030 [] Train (Loss=0.016 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0031 [] Train (Loss=0.015 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0032 [] Train (Loss=0.015 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0033 [] Train (Loss=0.015 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0034 [] Train (Loss=0.015 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0035 [] Train (Loss=0.015 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0036 [] Train (Loss=0.015 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0037 [] Train (Loss=0.015 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0038 [] Train (Loss=0.015 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0039 [] Train (Loss=0.015 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0040 [] Train (Loss=0.015 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0041 [] Train (Loss=0.015 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0042 [] Train (Loss=0.015 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0043 [] Train (Loss=0.015 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0044 [] Train (Loss=0.015 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0045 [] Train (Loss=0.015 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0046 [] Train (Loss=0.015 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0047 [] Train (Loss=0.015 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0048 [] Train (Loss=0.015 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0049 [] Train (Loss=0.015 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0050 [] Train (Loss=0.015 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0051 [] Train (Loss=0.015 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0052 [] Train (Loss=0.015 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0053 [] Train (Loss=0.015 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0054 [] Train (Loss=0.015 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0055 [] Train (Loss=0.015 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0063 [] Train (Loss=0.015 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0064 [] Train (Loss=0.015 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0065 [] Train (Loss=0.015 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0066 [] Train (Loss=0.015 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0067 [] Train (Loss=0.015 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0068 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0069 [] Train (Loss=0.015 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0070 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0071 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0072 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0073 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0074 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0075 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0076 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0077 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0078 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0079 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0080 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0081 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0082 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0083 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0084 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0085 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0086 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0087 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0088 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0089 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0090 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0091 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0092 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0093 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0094 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0095 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0096 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0097 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0098 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0099 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0100 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0101 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0102 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0103 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0104 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0105 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0106 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0107 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0108 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0109 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0110 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0111 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0112 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0113 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0114 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0115 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0116 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0117 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0118 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0119 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0120 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0121 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0122 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0123 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0124 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0125 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0126 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0127 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0128 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0129 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0130 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0131 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0132 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0133 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0134 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0135 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0136 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0137 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0138 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0139 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0140 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0141 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0142 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0143 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0144 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0145 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0146 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0147 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0148 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0149 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0150 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0151 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0152 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0153 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0154 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0155 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0156 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0157 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0158 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0159 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0160 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0161 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0162 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0163 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0164 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0165 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch 0166 [17920/36784 (48.7)%] 		 Loss: 0.013
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Epoch: 0222 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0223 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0224 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0225 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0226 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0227 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0228 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0229 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0230 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0231 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0232 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0233 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0234 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0235 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0236 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0237 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0238 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0239 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0240 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0241 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0242 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0243 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0244 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0245 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0246 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0247 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0248 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0249 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0250 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0251 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0252 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0261 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0262 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0263 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0264 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0265 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0266 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0267 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0268 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0269 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0270 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0271 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0272 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0273 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0274 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0275 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0276 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0277 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0278 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0279 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0280 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0281 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0282 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0283 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0284 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0285 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0286 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0287 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0288 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0289 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0290 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0291 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0292 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0293 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0294 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0295 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0296 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0297 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0298 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0299 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0300 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0301 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0302 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0303 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0304 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0305 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0306 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0307 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0308 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0309 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0310 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0311 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0312 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0313 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0314 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0315 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0316 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0317 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0318 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0319 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0320 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0321 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0322 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0323 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0324 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0325 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0326 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0327 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0328 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0329 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0330 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0331 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0332 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0333 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0334 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0335 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0336 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0337 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0338 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0339 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0340 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0341 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0342 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0343 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0344 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0345 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0346 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0347 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0348 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0349 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0350 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0351 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0352 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0353 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0354 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0355 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0356 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0357 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0358 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0359 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0360 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0361 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0362 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0363 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0364 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0365 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0366 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0367 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0368 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0369 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0370 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0371 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0372 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0373 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0374 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0375 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0376 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0377 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0378 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0379 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0380 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0381 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0382 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0383 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0384 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0385 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0386 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0387 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0388 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0389 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0390 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0391 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0392 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0393 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0394 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0395 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0396 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0397 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0398 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0399 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0400 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0401 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0402 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0403 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0404 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0405 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0406 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0407 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0408 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0409 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0410 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0411 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0412 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0413 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0414 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0415 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0416 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0417 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0418 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0419 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0420 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0421 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0422 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0423 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0424 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0425 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0426 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0427 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0428 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0429 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0430 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0431 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0432 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0433 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0434 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0435 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0436 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0437 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0438 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0439 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0440 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0441 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0442 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0443 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0444 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0445 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0446 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0447 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0448 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0449 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0450 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0451 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0452 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0453 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0454 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0455 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0456 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0457 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0458 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0459 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0460 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0461 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0462 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0463 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0464 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0465 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0466 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0467 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0468 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0469 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0470 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0471 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0472 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0473 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0474 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0475 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0476 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0477 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0478 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0479 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0480 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0481 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0482 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0483 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0484 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0485 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0486 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0487 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0488 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0489 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0490 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0491 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0492 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0493 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0494 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0495 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0496 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0497 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0498 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0499 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0500 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0501 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0502 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0503 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0504 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0505 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0506 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0507 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0508 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0509 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0510 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0511 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0512 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0513 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0514 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0515 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0516 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0517 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0518 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0519 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0520 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0521 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0522 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0523 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0524 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0525 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0526 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0527 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0528 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0529 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0530 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0531 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0532 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0533 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0534 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0535 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0536 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0537 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0538 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0539 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0540 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0541 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0542 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0543 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0544 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0545 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0546 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0547 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0548 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0549 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0550 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0551 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0552 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0553 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0554 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0555 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0556 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0557 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0558 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0559 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0560 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0561 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0562 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0563 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0564 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0565 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0566 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0567 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0568 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0569 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0570 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0571 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0572 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0573 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 0574 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0575 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0576 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0577 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0578 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0579 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0580 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0581 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0582 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0583 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0584 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0585 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0586 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0587 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0588 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 0589 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0590 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0591 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0592 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0593 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0594 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0595 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0596 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0597 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0598 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0599 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0600 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0601 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0602 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0603 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0604 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0605 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0606 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0607 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0608 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0609 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0610 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0611 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0612 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0613 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0614 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0615 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0616 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0617 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0618 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0619 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0620 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0621 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0622 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0623 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0624 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0625 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0626 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0627 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0628 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0629 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0630 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0631 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0632 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0633 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0634 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0635 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0636 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0637 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0638 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0639 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0640 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0641 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0642 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0643 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0644 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0645 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0646 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0647 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0648 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0649 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0650 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0651 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0652 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0653 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0654 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0655 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0656 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0657 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0658 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0659 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0660 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0661 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0662 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0663 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0664 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0665 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0666 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0667 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0668 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0669 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0670 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0671 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0672 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0673 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0674 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0675 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0676 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0677 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0678 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 0679 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0680 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 0681 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0682 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0683 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0684 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0685 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0686 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0687 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0688 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0689 [] Train (Loss=0.010 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# ...
# Epoch: 1012 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1013 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1014 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1015 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1016 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1017 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1018 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1019 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1020 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1021 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1022 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 1023 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1024 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1025 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1026 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 1027 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1028 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1029 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 1030 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1031 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1032 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1033 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1034 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1035 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1036 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1037 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 1038 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1039 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1040 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1041 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1042 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1043 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1044 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1045 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1046 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1047 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1048 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 1049 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1050 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1051 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1052 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1053 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1054 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1055 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1056 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1057 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1058 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1059 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1060 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1061 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1062 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1063 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1064 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1065 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1066 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1067 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1068 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1069 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1070 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1071 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1072 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1073 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1074 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1075 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1076 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1077 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1078 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1079 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1080 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1081 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1082 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1083 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1084 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1085 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1086 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1087 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1088 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1089 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1090 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1091 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1092 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1093 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1094 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1095 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1096 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1097 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1098 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1099 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1100 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1101 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1102 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1103 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1104 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1105 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1106 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1107 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1108 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1109 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1110 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1111 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1112 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1113 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1114 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1115 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1116 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1117 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1118 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1119 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1120 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1121 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1122 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1123 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1124 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1125 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1126 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1127 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1128 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1129 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1130 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1131 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1132 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1133 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1134 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1135 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1136 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1137 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1138 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1139 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1140 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1141 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1142 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1143 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1144 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1145 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1146 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1147 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1148 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1149 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1150 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1151 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1152 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1153 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1154 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1155 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1156 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1157 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1158 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1159 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1160 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1161 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1162 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1163 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1164 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1165 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1166 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1167 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1168 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1169 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1170 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1171 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1172 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1173 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1174 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1175 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1176 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1177 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1178 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1179 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1180 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1181 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.018 | HL=0.000)
# Epoch: 1182 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1183 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1184 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1185 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1186 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1187 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1188 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.018 | HL=0.000)
# Epoch: 1189 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1190 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1191 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1192 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1193 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1194 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1195 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1196 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1197 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1198 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1199 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1200 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1201 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1202 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1203 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1204 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1205 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1206 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1207 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1208 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1209 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1210 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1211 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1212 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1213 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1214 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1215 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1216 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1217 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 1218 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.018 | HL=0.000)
# Epoch 1219 [30720/36784 (83.5)%] 		 Loss: 0.008

# %%
# Plot training and test errors
plt.plot(range(epoch + 1), test_loss, 'o', c='black', ms=5, label='Test')
plt.plot(range(epoch + 1), epoch_loss, 'o', c='red', ms=5, label='Training')
plt.xlabel("n of epochs", size=14)
plt.ylabel("MAE", size=14)
plt.legend(fontsize=14)
plt.tight_layout()
plt.savefig("Train_test_errors.png", dpi=200)


predictions = model_predictions(nn_gap, x_test, device, batch_size=64)

px = predictions.reshape(-1)
py = y_test.reshape(-1)

# Generate linear fit
slope, intercept, r_value, p_value, std_err = stats.linregress(px, py)
line = slope * px + intercept
conf = std_err * 2.58  # 99% confidence interval

fig, axs = plt.subplots(1, 1, dpi=80)
axs.tick_params(axis="both", which="major", labelsize=12)

axs.plot(px, py, "o", color="xkcd:tomato", aa=True, alpha=0.6)
axs.plot(px, line, color="xkcd:azure", aa=True, alpha=0.6)

axs.set_ylabel(r"Target Values (Hartree)", fontsize=14)
axs.set_xlabel("Predicted Values (Hartree)", fontsize=14)
fig.text(0.13, 0.90, "R$^2$ = " + str(round(r_value**2, 2)), ha="left", fontsize=13)

fig.tight_layout()
plt.savefig("Linear_reg.png", dpi=200)

# Save the model
torch.save('nn_gap.pt')
