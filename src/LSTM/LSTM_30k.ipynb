# %%
# !pip install rdkit pysmiles prettytable pybel;
# Out:
# Requirement already satisfied: rdkit in /opt/conda/lib/python3.11/site-packages (2024.9.6)
# Requirement already satisfied: pysmiles in /opt/conda/lib/python3.11/site-packages (2.0.0)
# Requirement already satisfied: prettytable in /opt/conda/lib/python3.11/site-packages (3.16.0)
# Requirement already satisfied: pybel in /opt/conda/lib/python3.11/site-packages (0.15.5)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.11/site-packages (from rdkit) (1.26.4)
# Requirement already satisfied: Pillow in /opt/conda/lib/python3.11/site-packages (from rdkit) (10.4.0)
# Requirement already satisfied: pbr in /opt/conda/lib/python3.11/site-packages (from pysmiles) (6.1.1)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.11/site-packages (from pysmiles) (3.3)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.11/site-packages (from prettytable) (0.2.13)
# Requirement already satisfied: sqlalchemy in /opt/conda/lib/python3.11/site-packages (from pybel) (2.0.32)
# Requirement already satisfied: click in /opt/conda/lib/python3.11/site-packages (from pybel) (8.1.7)
# Requirement already satisfied: click-plugins in /opt/conda/lib/python3.11/site-packages (from pybel) (1.1.1)
# Requirement already satisfied: bel-resources>=0.0.3 in /opt/conda/lib/python3.11/site-packages (from pybel) (0.0.3)
# Requirement already satisfied: more-itertools in /opt/conda/lib/python3.11/site-packages (from pybel) (10.7.0)
# Requirement already satisfied: requests in /opt/conda/lib/python3.11/site-packages (from pybel) (2.32.3)
# Requirement already satisfied: requests-file in /opt/conda/lib/python3.11/site-packages (from pybel) (2.1.0)
# Requirement already satisfied: pyparsing in /opt/conda/lib/python3.11/site-packages (from pybel) (3.1.4)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.11/site-packages (from pybel) (4.66.5)
# Requirement already satisfied: humanize in /opt/conda/lib/python3.11/site-packages (from pybel) (4.12.3)
# Requirement already satisfied: tabulate in /opt/conda/lib/python3.11/site-packages (from pybel) (0.9.0)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.11/site-packages (from pybel) (2.1.4)
# Requirement already satisfied: jsonschema in /opt/conda/lib/python3.11/site-packages (from pybel) (4.23.0)
# Requirement already satisfied: bioregistry in /opt/conda/lib/python3.11/site-packages (from pybel) (0.12.13)
# Requirement already satisfied: ratelimit in /opt/conda/lib/python3.11/site-packages (from pybel) (2.2.1)
# Requirement already satisfied: pystow>=0.1.2 in /opt/conda/lib/python3.11/site-packages (from pybel) (0.7.0)
# Requirement already satisfied: psycopg2-binary in /opt/conda/lib/python3.11/site-packages (from pybel) (2.9.10)
# Requirement already satisfied: multisplitby in /opt/conda/lib/python3.11/site-packages (from bel-resources>=0.0.3->pybel) (0.0.1)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.11/site-packages (from pystow>=0.1.2->pybel) (4.12.2)
# Requirement already satisfied: more_click>=0.1.2 in /opt/conda/lib/python3.11/site-packages (from bioregistry->pybel) (0.1.2)
# Requirement already satisfied: pydantic>=2.0 in /opt/conda/lib/python3.11/site-packages (from pydantic[email]>=2.0->bioregistry->pybel) (2.8.2)
# Requirement already satisfied: curies>=0.7.0 in /opt/conda/lib/python3.11/site-packages (from bioregistry->pybel) (0.10.16)
# Requirement already satisfied: attrs>=22.2.0 in /opt/conda/lib/python3.11/site-packages (from jsonschema->pybel) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/conda/lib/python3.11/site-packages (from jsonschema->pybel) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/conda/lib/python3.11/site-packages (from jsonschema->pybel) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/conda/lib/python3.11/site-packages (from jsonschema->pybel) (0.20.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.11/site-packages (from pandas->pybel) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.11/site-packages (from pandas->pybel) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.11/site-packages (from pandas->pybel) (2024.1)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.11/site-packages (from pbr->pysmiles) (72.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests->pybel) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests->pybel) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests->pybel) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests->pybel) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/lib/python3.11/site-packages (from sqlalchemy->pybel) (3.0.3)
# Requirement already satisfied: pytrie in /opt/conda/lib/python3.11/site-packages (from curies>=0.7.0->bioregistry->pybel) (0.4.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/conda/lib/python3.11/site-packages (from pydantic>=2.0->pydantic[email]>=2.0->bioregistry->pybel) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /opt/conda/lib/python3.11/site-packages (from pydantic>=2.0->pydantic[email]>=2.0->bioregistry->pybel) (2.20.1)
# Requirement already satisfied: email-validator>=2.0.0 in /opt/conda/lib/python3.11/site-packages (from pydantic[email]>=2.0->bioregistry->pybel) (2.2.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->pybel) (1.16.0)
# Requirement already satisfied: dnspython>=2.0.0 in /opt/conda/lib/python3.11/site-packages (from email-validator>=2.0.0->pydantic[email]>=2.0->bioregistry->pybel) (2.7.0)
# Requirement already satisfied: sortedcontainers in /opt/conda/lib/python3.11/site-packages (from pytrie->curies>=0.7.0->bioregistry->pybel) (2.4.0)

# %%
# Import required packages

import numpy as np
import pandas as pd
import torch
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from torch.utils.data import TensorDataset, DataLoader
from prettytable import PrettyTable
import multiprocessing
from scipy import stats
import os, sys
import time

# %%
start = time.time()

file_dir = os.path.dirname("../")
sys.path.append(file_dir)

from anima.smiles import SMILES

sml = SMILES()

cores = int(multiprocessing.cpu_count())
print(f"Cores: {cores}, GPUs: {torch.cuda.device_count()}")

# Read the database
print("\n Reading the database \n")
database = pd.read_csv("../anima-master/databases/OMEAD_41801.csv", nrows=30000)
database["homo_lumo_gap"] = database.lumo - database.homo

print(f" \n Database shape {database.shape} \n")
# Out:
# Cores: 24, GPUs: 1
#
#  Reading the database
#
#
#  Database shape (30000, 21)

# %%
# Perform database cleaning
clean = ["Se", "Zn", "se", "zn", "6", "-"]
for sm in database.smiles:
    for ii in clean:
        if ii in sm:
            indx = database[database.smiles == sm].index
            database.drop(index=indx, inplace=True)
            continue
        count = 0
        for entry in sm:
            if entry.isalpha():
                count += 1
        if count > 30:
            indx = database[database.smiles == sm].index
            database.drop(index=indx, inplace=True)
            
indx = database[database.oxidation <= 6.0].index
database.drop(index=indx, inplace=True)

print(f"\n New database shape {database.shape} \n")

# Identifying redox unstable structures
print(f"Number of redox unstable molecules = {len(database[database.redox_stable == 'no'])}")

print("\n Selecting redox stable structures \n")
train_db = database[database.redox_stable == "yes"]

print(f"\n Trainable structures = {len(train_db)}")

print("\n Data preprocessing \n")

smiles = np.array(train_db.smiles)

# Reading homo lumo gap
gap = np.array(train_db.homo_lumo_gap)

# Defining SMILES vocabulary
print("\n Defining SMILES vocabulary \n")
vocab = sml.smilesVOC(smiles, n_jobs=cores)
vocab_size = len(vocab)

print(f"\n Vocab size: {vocab_size} \n")

# counting elements / smiles participation
selected_smiles = smiles

Vtotal = {}

# Initialize
for ii in vocab:
    Vtotal[ii] = 0

for i in range(len(selected_smiles)):
    for ii in vocab:
        if ii in selected_smiles[i] or ii.lower() in selected_smiles[i]:
            Vtotal[ii] += 1

voc_temp = list()

voc_temp.extend(vocab[0:6])
voc_temp.extend(vocab[7:15])
voc_temp.extend(vocab[17:])

full_vocab = vocab
vocab = voc_temp

vocab_size = len(vocab)
print(f"\n New vocab size after cleaning: {vocab_size} \n")

print("\n Saving vocabulary \n")

# Saving the vocabulary
with open("vocab.dat", "w") as f:
    for i in vocab:
        f.write(str(i) + "\n")

# Saving the full full vocabulary
with open("full_vocab.dat", "w") as f:
    for i in full_vocab:
        f.write(str(i) + "\n")
# Out:
#  New database shape (28242, 21)
#
# Number of redox unstable molecules = 6938
#
#  Selecting redox stable structures
#
#
#  Trainable structures = 21304
#
#  Data preprocessing
#
#
#  Defining SMILES vocabulary
# [Parallel(n_jobs=24)]: Using backend ThreadingBackend with 24 concurrent workers.
# [Parallel(n_jobs=24)]: Done   2 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=24)]: Done 152 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=24)]: Done 402 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=24)]: Done 752 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=24)]: Done 1202 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=24)]: Done 1752 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=24)]: Done 2402 tasks      | elapsed:    5.0s
# [Parallel(n_jobs=24)]: Done 3152 tasks      | elapsed:    7.6s
# [Parallel(n_jobs=24)]: Done 4002 tasks      | elapsed:   10.5s
# [Parallel(n_jobs=24)]: Done 4952 tasks      | elapsed:   13.8s
# [Parallel(n_jobs=24)]: Done 6002 tasks      | elapsed:   17.4s
# [Parallel(n_jobs=24)]: Done 7152 tasks      | elapsed:   21.6s
# [Parallel(n_jobs=24)]: Done 8402 tasks      | elapsed:   25.9s
# [Parallel(n_jobs=24)]: Done 9752 tasks      | elapsed:   30.7s
# [Parallel(n_jobs=24)]: Done 11202 tasks      | elapsed:   36.0s
# [Parallel(n_jobs=24)]: Done 12752 tasks      | elapsed:   41.4s
# [Parallel(n_jobs=24)]: Done 14402 tasks      | elapsed:   47.4s
# [Parallel(n_jobs=24)]: Done 16152 tasks      | elapsed:   53.6s
# [Parallel(n_jobs=24)]: Done 18002 tasks      | elapsed:   59.6s
# [Parallel(n_jobs=24)]: Done 19952 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=24)]: Done 21304 out of 21304 | elapsed:  1.2min finished
#  Vocab size: 22
#
#
#  New vocab size after cleaning: 19
#
#
#  Saving vocabulary

# %%
print("\n Preparing SMILES for PyTorch \n")

# Converting SMILES into sequences or 1h tensors

# for embeddings
all_sequences = []

l = 1
for i in smiles:
    print(l, end="\r")
    all_sequences.append(torch.tensor(sml.smilesToSequence(i, vocab)))
    l += 1

# for embedding
packing = torch.nn.utils.rnn.pack_sequence(
    all_sequences,
    enforce_sorted=False
)

packing_padding = torch.nn.utils.rnn.pad_packed_sequence(
    packing,
    batch_first=True
)

# Check dimensions

# for embeddings
# BATCH x SEQUENCE x INFO
print(f"\n Check packing shape {packing_padding[0][:, :, :].size()}")

print("\n Train / test split \n")

# Final data format for NN
# for embedding
temp = packing_padding[0][:, :, 0]

random_state = 1
test_size = 0.12

# inputs
x_train, x_test = train_test_split(
    temp.numpy(),
    test_size=test_size,
    random_state=1
)
del temp

# targets
y_train_gap, y_test_gap = train_test_split(
    gap,
    test_size=test_size,
    random_state=1
)

# max length of sequence in batch
print(f"\n Max length of tensor sequences: {x_train.shape}")

# for embeddings
max_length = x_train.shape[-1]
print(f"\nDebugging ### max_length: {max_leng}")

print(f"\n Test size: {x_test.shape} \n")
print(f"\n Train size: {x_train.shape} \n")

# ---
# # Networks
# ## Defining the NN class and tools
print("\n Starting the NN configs \n")

# Checking CUDA
use_cuda = True
print(f"Cuda available: {torch.cuda.is_available()}")
device = torch.device(
    "cuda" if (use_cuda and torch.cuda.is_available()) else "cpu"
)
torch.cuda.set_per_process_memory_fraction(0.7, device=0) # Limits GPU usage to 70%
# Out:
#  Preparing SMILES for PyTorch
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 9
#       6 all_sequences = []
#       8 l = 1
# ----> 9 for i in smiles:
#      10     print(l, end="\r")
#      11     all_sequences.append(torch.tensor(sml.smilesToSequence(i, vocab)))
#
# NameError: name 'smiles' is not defined

# %%
# Tools
def count_parameters(model):
    # function to return the params/layers of the model
    table = PrettyTable(["Modules", "Parameters"])
    total_params = 0
    for name, parameter in model.named_parameters():
        if not parameter.requires_grad:
            continue
        param = parameter.numel()
        table.add_row([name, param])
        total_params += param
    print(table)
    print(f"Total Trainable Params: {total_params}")
    print('\n\nModel Details\n')
    for i in np.array(list(model.named_modules())[1:])[:, :]:
        print(i)

def model_evaluation(model, x_test, y_test, device):
    # Performance on test
    batch_size = 64

    test_data = TensorDataset(
        torch.tensor(x_test),
        torch.tensor(y_test),
        
    )
    test_loader = DataLoader(
        test_data,
        shuffle=False,
        batch_size=batch_size,
        drop_last=False
    )

    running_mae = []
    running_mse = []
    mae = torch.nn.L1Loss().to(device)
    mse = torch.nn.SmoothL1Loss().to(device)

    model.eval().to(device)

    with torch.no_grad():
        for batch_idx, data in enumerate(test_loader):
            # get the inputs; data is a list of [inputs, labels]
            inputs, targets = data
            inputs, targets = inputs.to(device), targets.to(device)
            targets = targets.double()

            output = model(inputs)

            loss_mae = mae(output, targets)
            loss_mse = mse(output, targets)

            running_mae.append(loss_mae.item())
            running_mse.append(loss_mse.item())

    model.train()
    return np.mean(running_mae), np.mean(running_mse)

def model_predictions(model, x, device, batch_size = 64):
    # predictions

    model.eval().to(device)

    pred_data = TensorDataset(torch.tensor(x))
    pred_loader = DataLoader(
        pred_data,
        shuffle=False,
        batch_size=batch_size,
        drop_last=False,
    )

    batches = len(x) / batch_size

    with torch.no_grad():
        for batch_idx, data in enumerate(pred_loader):
            print(f"Batch: {batch_idx + 1:010.2f} of {batches:010.2f}", end="\r")
            inputs = data[0]
            inputs = inputs.to(device)

            output = model(inputs)
            if batch_idx == 0:
                temp = output.cpu().detach().numpy()
            else:
                temp = np.append(temp, output.cpu().detach().numpy())
            del inputs, output

    return np.reshape(temp, -1)

# %%
# Defining the NN model
class NN(torch.nn.Module):
    def __init__(self, hidden_dim, output_dim, n_layers, decoder_in, decoder_out, vocab_size, emb_dim, max_length, dropout):
        super().__init__()
        self.hidden_dim = hidden_dim
        self.n_layers = n_layers

        self.lstmA = torch.nn.LSTM(emb_dim, hidden_dim, n_layers, batch_first=True, dropout=dropout)
        self.lstmB = torch.nn.LSTM(emb_dim, hidden_dim, n_layers, batch_first=True, dropout=dropout)
        self.lstmC = torch.nn.LSTM(emb_dim, hidden_dim, n_layers, batch_first=True, dropout=dropout)
        self.lstmD = torch.nn.LSTM(emb_dim, hidden_dim, n_layers, batch_first=True, dropout=dropout)

        self.fcA = torch.nn.Linear(hidden_dim, decoder_in)
        self.fcB = torch.nn.Linear(hidden_dim, decoder_in)
        self.fcC = torch.nn.Linear(hidden_dim, decoder_in)
        self.fcD = torch.nn.Linear(hidden_dim, decoder_in)

        self.decoder = torch.nn.Linear(max_length * 4 * decoder_in, decoder_out)
        self.pre_output = torch.nn.Linear(decoder_out, 1)
        self.output = torch.nn.Linear(decoder_out, output_dim)

        self.activation = torch.nn.Mish()
        self.embeddings = torch.nn.Embedding(vocab_size + 1, emb_dim, max_norm=1.0, padding_idx=0)
        self.dropout = torch.nn.Dropout(dropout)

    def forward(self, inputs):
        batch = len(inputs)
        inputs = self.embeddings(inputs)

        hidden, cell = self.initHidden(batch, self.hidden_dim)
        lstmA, _ = self.lstmA(inputs, (hidden, cell))
        hidden, cell = self.initHidden(batch, self.hidden_dim)
        lstmB, _ = self.lstmB(inputs, (hidden, cell))
        hidden, cell = self.initHidden(batch, self.hidden_dim)
        lstmC, _ = self.lstmC(inputs, (hidden, cell))
        hidden, cell = self.initHidden(batch, self.hidden_dim)
        lstmD, _ = self.lstmD(inputs, (hidden, cell))
        

        fcA = self.fcA(lstmA)
        fcB = self.fcB(lstmB)
        fcC = self.fcC(lstmC)
        fcD = self.fcD(lstmD)

        cat = torch.cat((fcA, fcB, fcC, fcD), -1)
        cat = cat.reshape(batch, -1)
        cat = self.activation(cat)

        decoder = self.decoder(cat)
        decoder = self.activation(decoder)
        decoder = self.dropout(decoder)

        output = self.output(decoder)

        return output[:, 0]

    def initHidden(self, batch_size, hidden_dim):
        return (torch.zeros(self.n_layers, batch_size, hidden_dim, dtype=torch.float, device=device),
               torch.zeros(self.n_layers, batch_size, hidden_dim, dtype=torch.float, device=device))

# %%
print("\n Gap NN \n")

epochs = 2000
all_data = len(x_train)
log = 10

decoder_in = 32
decoder_out = 64
hidden_dim = 128
n_layers = 3
emb_dim = 256
output_dim = 1
batch_size = 256
dropout = 0.15
weight_decay = 1e-5

nn_gap = NN(hidden_dim, output_dim, n_layers, decoder_in, decoder_out, vocab_size, emb_dim, max_length, dropout)
nn_gap = nn_gap.float().to(device)

# loss
metric = torch.nn.SmoothL1Loss().double()
optimizer = torch.optim.Adam(nn_gap.parameters(), lr=0.001, weight_decay=weight_decay)

# setting the dataloader
train_data = TensorDataset(torch.tensor(x_train), torch.tensor(y_train_gap))
train_loader = DataLoader(train_data, shuffle=True, batch_size=batch_size, drop_last=False, pin_memory=True)
# Out:
#  Gap NN

# %%
epoch_loss = []
test_loss = []
for epoch in range(epochs):

    running_loss = []
    running_metric = []
    for batch_idx, data in enumerate(train_loader):
        # get the inputs; data is a list of [inputs, labels]
        inputs = data[0]
        targets = data[1]
        inputs, targets = inputs.to(device), targets.to(device)
        targets = targets.double()

        optimizer.zero_grad()

        output = nn_gap(inputs)

        loss = torch.mean(torch.abs(targets - output))
        loss.backward()
        optimizer.step()

        # Print statistics every log
        running_loss.append(loss.item())
        running_metric.append(metric(output, targets).item())
        if batch_idx % log == 0:
            print(f"Epoch {epoch+1:04d} [{batch_idx * len(inputs):05d}/{all_data:05d} ({100 * batch_idx * batch_size / len(train_data):04.1f})%] \t\t Loss: {np.mean(running_loss):02.3f}", end="\r")

    epoch_loss.append(np.mean(running_loss))
    test_mae, test_mse = model_evaluation(nn_gap, x_test, y_test_gap, device)
    test_loss.append(test_mae)

    print(f"Epoch: {epoch + 1:04d} [] Train (Loss={np.mean(running_loss):02.3f} | Metric={np.mean(running_metric):02.3f})\tVal. (MAE={test_mae:02.3f} | HL={test_mse:02.3f})", end="\n")

print("\n")
print(f"\n Train Loss: {round(epoch_loss[-1], 2)}")
print(f"\n Test MAE: {round(test_loss[-1], 2)}")
print("\n Finished training")

print("\n Saving model \n")

# save
torch.save(nn_gap.state_dict(), "nn_gap.pt")
torch.save(nn_gap, "nn_gap.pt_full")
# Out:
# Epoch: 0001 [] Train (Loss=0.045 | Metric=0.002)	Val. (MAE=0.024 | HL=0.000)
# Epoch: 0002 [] Train (Loss=0.023 | Metric=0.000)	Val. (MAE=0.023 | HL=0.000)
# Epoch: 0003 [] Train (Loss=0.022 | Metric=0.000)	Val. (MAE=0.018 | HL=0.000)
# Epoch: 0004 [] Train (Loss=0.022 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 0005 [] Train (Loss=0.020 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 0006 [] Train (Loss=0.020 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 0007 [] Train (Loss=0.020 | Metric=0.000)	Val. (MAE=0.022 | HL=0.000)
# Epoch: 0008 [] Train (Loss=0.019 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 0009 [] Train (Loss=0.019 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 0010 [] Train (Loss=0.018 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 0011 [] Train (Loss=0.019 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 0012 [] Train (Loss=0.018 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 0013 [] Train (Loss=0.018 | Metric=0.000)	Val. (MAE=0.020 | HL=0.000)
# Epoch: 0014 [] Train (Loss=0.019 | Metric=0.000)	Val. (MAE=0.018 | HL=0.000)
# Epoch: 0015 [] Train (Loss=0.018 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 0016 [] Train (Loss=0.018 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0017 [] Train (Loss=0.018 | Metric=0.000)	Val. (MAE=0.018 | HL=0.000)
# Epoch: 0018 [] Train (Loss=0.018 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0019 [] Train (Loss=0.018 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 0020 [] Train (Loss=0.017 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 0021 [] Train (Loss=0.018 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 0022 [] Train (Loss=0.018 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0023 [] Train (Loss=0.017 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 0024 [] Train (Loss=0.017 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0025 [] Train (Loss=0.017 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0026 [] Train (Loss=0.017 | Metric=0.000)	Val. (MAE=0.022 | HL=0.000)
# Epoch: 0027 [] Train (Loss=0.018 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 0028 [] Train (Loss=0.017 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0029 [] Train (Loss=0.017 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0030 [] Train (Loss=0.017 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0031 [] Train (Loss=0.017 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0032 [] Train (Loss=0.017 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0033 [] Train (Loss=0.017 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0034 [] Train (Loss=0.017 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0035 [] Train (Loss=0.017 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 0036 [] Train (Loss=0.017 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0037 [] Train (Loss=0.017 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0038 [] Train (Loss=0.017 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 0039 [] Train (Loss=0.017 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0040 [] Train (Loss=0.017 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0041 [] Train (Loss=0.017 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 0042 [] Train (Loss=0.016 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0043 [] Train (Loss=0.017 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0044 [] Train (Loss=0.016 | Metric=0.000)	Val. (MAE=0.018 | HL=0.000)
# Epoch: 0045 [] Train (Loss=0.017 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0046 [] Train (Loss=0.017 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0047 [] Train (Loss=0.017 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 0048 [] Train (Loss=0.016 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0049 [] Train (Loss=0.016 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 0050 [] Train (Loss=0.016 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0051 [] Train (Loss=0.016 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0052 [] Train (Loss=0.017 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0053 [] Train (Loss=0.016 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0054 [] Train (Loss=0.016 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0055 [] Train (Loss=0.016 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0056 [] Train (Loss=0.016 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0057 [] Train (Loss=0.016 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0058 [] Train (Loss=0.016 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0059 [] Train (Loss=0.016 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0060 [] Train (Loss=0.016 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 0061 [] Train (Loss=0.016 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0062 [] Train (Loss=0.016 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0063 [] Train (Loss=0.016 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0064 [] Train (Loss=0.016 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0065 [] Train (Loss=0.016 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0066 [] Train (Loss=0.016 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 0067 [] Train (Loss=0.016 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0068 [] Train (Loss=0.016 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0069 [] Train (Loss=0.016 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0070 [] Train (Loss=0.016 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0071 [] Train (Loss=0.016 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0072 [] Train (Loss=0.016 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 0073 [] Train (Loss=0.016 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0074 [] Train (Loss=0.016 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0075 [] Train (Loss=0.016 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0076 [] Train (Loss=0.016 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0077 [] Train (Loss=0.016 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0078 [] Train (Loss=0.016 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0079 [] Train (Loss=0.016 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0080 [] Train (Loss=0.016 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0081 [] Train (Loss=0.016 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0082 [] Train (Loss=0.016 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0083 [] Train (Loss=0.016 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0084 [] Train (Loss=0.016 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0085 [] Train (Loss=0.016 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0086 [] Train (Loss=0.016 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0087 [] Train (Loss=0.016 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0088 [] Train (Loss=0.016 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0089 [] Train (Loss=0.015 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0090 [] Train (Loss=0.016 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0091 [] Train (Loss=0.016 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0092 [] Train (Loss=0.015 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0093 [] Train (Loss=0.015 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0094 [] Train (Loss=0.016 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0095 [] Train (Loss=0.015 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0096 [] Train (Loss=0.015 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0097 [] Train (Loss=0.015 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0098 [] Train (Loss=0.015 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0099 [] Train (Loss=0.015 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0100 [] Train (Loss=0.015 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0101 [] Train (Loss=0.015 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0102 [] Train (Loss=0.015 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0103 [] Train (Loss=0.015 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0104 [] Train (Loss=0.015 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0105 [] Train (Loss=0.015 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0106 [] Train (Loss=0.015 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0107 [] Train (Loss=0.015 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0108 [] Train (Loss=0.015 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0109 [] Train (Loss=0.015 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0110 [] Train (Loss=0.015 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0111 [] Train (Loss=0.015 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0112 [] Train (Loss=0.015 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0113 [] Train (Loss=0.015 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0114 [] Train (Loss=0.015 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0115 [] Train (Loss=0.015 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0116 [] Train (Loss=0.015 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0117 [] Train (Loss=0.015 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0118 [] Train (Loss=0.015 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0119 [] Train (Loss=0.015 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0120 [] Train (Loss=0.015 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0121 [] Train (Loss=0.015 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0122 [] Train (Loss=0.015 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0123 [] Train (Loss=0.015 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0124 [] Train (Loss=0.015 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0125 [] Train (Loss=0.015 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0126 [] Train (Loss=0.015 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0127 [] Train (Loss=0.015 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0128 [] Train (Loss=0.015 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0129 [] Train (Loss=0.015 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0130 [] Train (Loss=0.015 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0131 [] Train (Loss=0.015 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0132 [] Train (Loss=0.015 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0133 [] Train (Loss=0.015 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0134 [] Train (Loss=0.015 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0135 [] Train (Loss=0.015 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0136 [] Train (Loss=0.015 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0137 [] Train (Loss=0.015 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0138 [] Train (Loss=0.015 | Metric=0.000)	Val. (MAE=0.017 | HL=0.000)
# Epoch: 0139 [] Train (Loss=0.015 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0140 [] Train (Loss=0.015 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0141 [] Train (Loss=0.015 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0142 [] Train (Loss=0.015 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0143 [] Train (Loss=0.015 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0144 [] Train (Loss=0.015 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0145 [] Train (Loss=0.015 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0146 [] Train (Loss=0.015 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0147 [] Train (Loss=0.015 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0148 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0149 [] Train (Loss=0.015 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0150 [] Train (Loss=0.015 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0151 [] Train (Loss=0.015 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0152 [] Train (Loss=0.015 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0153 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0154 [] Train (Loss=0.015 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0155 [] Train (Loss=0.015 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0156 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0157 [] Train (Loss=0.015 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0158 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0159 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0160 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0161 [] Train (Loss=0.015 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0162 [] Train (Loss=0.015 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0163 [] Train (Loss=0.015 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0164 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0165 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0166 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0167 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0168 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0169 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0170 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0171 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0172 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0173 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0174 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0175 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0176 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0177 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0178 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0179 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0180 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0181 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0182 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0183 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0184 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0185 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0186 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0187 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0188 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0189 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0190 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0191 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0192 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0193 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0194 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0195 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0196 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0197 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0198 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0199 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0200 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0201 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.016 | HL=0.000)
# Epoch: 0202 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0203 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0204 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0205 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0206 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0207 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0208 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0209 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0210 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0211 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0212 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0213 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0214 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0215 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0216 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0217 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0218 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0219 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0220 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0221 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0222 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0223 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0224 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0225 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0226 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0227 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0228 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0229 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0230 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0231 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0232 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0233 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0234 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0235 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0236 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0237 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0238 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0239 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0240 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0241 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0242 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0243 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0244 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0245 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0246 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0247 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0248 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0249 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0250 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0251 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0252 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0253 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0254 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0255 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0256 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0257 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0258 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0259 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0260 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0261 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0262 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0263 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0264 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0265 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0266 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0267 [] Train (Loss=0.014 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0268 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0269 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0270 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0271 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0272 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0273 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0274 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0275 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0276 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0277 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0278 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0279 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0280 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0281 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0282 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0283 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0284 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0285 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0286 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0287 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0288 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0289 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0290 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0291 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0292 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0293 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0294 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0295 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0296 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0297 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0298 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0299 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0300 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0301 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0302 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0303 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0304 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0305 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0306 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0307 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0308 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0309 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0310 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0311 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0312 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0313 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0314 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0315 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0316 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0317 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0318 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0319 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0320 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0321 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0322 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0323 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0324 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0325 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0326 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0327 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0328 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0329 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0330 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0331 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0332 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0333 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0334 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0335 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0336 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0337 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0338 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0339 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0340 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0341 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0342 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0343 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0344 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0345 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0346 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0347 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0348 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0349 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0350 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0351 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0352 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0353 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0354 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0355 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0356 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0357 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0358 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0359 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0360 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0361 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0362 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0363 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0364 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0365 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0366 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0367 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0368 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0369 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0370 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0371 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0372 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0373 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0374 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0375 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0376 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0377 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0378 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0379 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0380 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0381 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0382 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0383 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0384 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0385 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0386 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 0387 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0388 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0389 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0390 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0391 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0392 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0393 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0394 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0395 [] Train (Loss=0.013 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0396 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0397 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0398 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0399 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0400 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0401 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0402 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0403 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0404 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0405 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0406 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0407 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0408 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0409 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0410 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0411 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0412 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0413 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0414 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0415 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0416 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0417 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0418 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0419 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0420 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0421 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0422 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0423 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0424 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0425 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0426 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0427 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0428 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0429 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0430 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0431 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0432 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0433 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0434 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0435 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0436 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0437 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0438 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0439 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0440 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0441 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0442 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0443 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0444 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0445 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0446 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0447 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0448 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0449 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0450 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0451 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0452 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0453 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0454 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0455 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0456 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0457 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0458 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0459 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0460 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0461 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0462 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0463 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0464 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0465 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0466 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0467 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0468 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0469 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0470 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0471 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0472 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0473 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0474 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0475 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0476 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0477 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0478 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0479 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0480 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0481 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0482 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0483 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0484 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0485 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0486 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0487 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0488 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0489 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0490 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0491 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0492 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0493 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0494 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0495 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0496 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0497 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0498 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0499 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0500 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0501 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0502 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0503 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0504 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0505 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0506 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0507 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0508 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0509 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0510 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0511 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0512 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0513 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0514 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0515 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0516 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0517 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0518 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0519 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0520 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0521 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0522 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0523 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0524 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0525 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0526 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0527 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0528 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0529 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0530 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0531 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0532 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0533 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0534 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0535 [] Train (Loss=0.012 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0536 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0537 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0538 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0539 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0540 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0541 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0542 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0543 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0544 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0545 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0546 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0547 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0548 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0549 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0550 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0551 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0552 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0553 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0554 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0555 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0556 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0557 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0558 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0559 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0560 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0561 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0562 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0563 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0564 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0565 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0566 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0567 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0568 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0569 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0570 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0571 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0572 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0573 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0574 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0575 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0576 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0577 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0578 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0579 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0580 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0581 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0582 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0583 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0584 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0585 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0586 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0587 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0588 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0589 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0590 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0591 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0592 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0593 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0594 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0595 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0596 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0597 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0598 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0599 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0600 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0601 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0602 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0603 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0604 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0605 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0606 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0607 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0608 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0609 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0610 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0611 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0612 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0613 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0614 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0615 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0616 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0617 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0618 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0619 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0620 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0621 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 0622 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.013 | HL=0.000)
# Epoch: 0623 [] Train (Loss=0.011 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# ...
# Epoch: 1689 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1690 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1691 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 1692 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1693 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1694 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 1695 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1696 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1697 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1698 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1699 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 1700 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1701 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1702 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1703 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1704 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1705 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1706 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1707 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1708 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1709 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1758 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 1759 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1760 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1761 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1762 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1763 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1764 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1765 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 1766 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1767 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1768 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 1769 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1770 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 1771 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1772 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 1773 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1774 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 1775 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1776 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1777 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1778 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1779 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1780 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1781 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1782 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1783 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1784 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1785 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1786 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1787 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 1788 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1789 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 1790 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1791 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1792 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1793 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1794 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1795 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1796 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1797 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1798 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1799 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1800 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1801 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1802 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1803 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 1804 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1805 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1806 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1807 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1808 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1809 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 1810 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1811 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1812 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1813 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1814 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1815 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1816 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1817 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 1818 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 1819 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1820 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1821 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1822 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1823 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1824 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1825 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1826 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1827 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1828 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1829 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1830 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1831 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 1832 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1833 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1834 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1835 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1836 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1837 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1838 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1839 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1840 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1841 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 1842 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1843 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1844 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 1845 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1846 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1847 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1848 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 1849 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1850 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1851 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 1852 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 1853 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 1854 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1855 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1856 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 1857 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1858 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1859 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1860 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1861 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1862 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1863 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1864 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 1865 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1866 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1867 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1868 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 1869 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1870 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 1871 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 1872 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1873 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1874 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1875 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 1876 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1877 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1878 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1879 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1880 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1881 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1882 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1883 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1884 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 1885 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1886 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1887 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1888 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1889 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1890 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1891 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1892 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 1893 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1894 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1895 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1896 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 1897 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1898 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1899 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1900 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1901 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 1902 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1903 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1904 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1905 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1906 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1907 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1908 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1909 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1910 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1911 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1912 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1913 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1914 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1915 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1916 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1917 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1918 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1919 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1920 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1921 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1922 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1923 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1924 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1925 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1926 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 1927 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1928 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 1929 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1930 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 1931 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1932 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1933 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1934 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1935 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1936 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1937 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1938 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1939 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 1940 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch: 1941 [] Train (Loss=0.009 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1942 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.014 | HL=0.000)
# Epoch: 1943 [] Train (Loss=0.008 | Metric=0.000)	Val. (MAE=0.015 | HL=0.000)
# Epoch 1944 [12800/18747 (68.3)%] 		 Loss: 0.009

# %%
# Plot training and test errors
plt.plot(range(epoch + 1), test_loss, 'o', c='black', ms=5, label='Test')
plt.plot(range(epoch + 1), epoch_loss, 'o', c='red', ms=5, label='Training')
plt.xlabel("n of epochs", size=14)
plt.ylabel("MAE", size=14)
plt.legend(fontsize=14)
plt.tight_layout()
plt.savefig("gap_model_training.png", dpi=200)

predictions = model_predictions(nn_gap, x_test, device, batch_size=64)

px = predictions.reshape(-1)
py = y_test_gap.reshape(-1)

# Generate linear fit
slope, intercept, r_value, p_value, std_err = stats.linregress(px, py)
line = slope * px + intercept
conf = std_err * 2.58  # 99% confidence interval

fig, axs = plt.subplots(1, 1, dpi=80)
axs.tick_params(axis="both", which="major", labelsize=12)

axs.plot(px, py, "o", color="xkcd:tomato", aa=True, alpha=0.6)
axs.plot(px, line, color="xkcd:azure", aa=True, alpha=0.6)

axs.set_ylabel(r"Target Values (Hartree)", fontsize=14)
axs.set_xlabel("Predicted Values (Hartree)", fontsize=14)
fig.text(0.13, 0.90, "R$^2$ = " + str(round(r_value**2, 1)), ha="left", fontsize=13)

fig.tight_layout()
plt.savefig("gap_model_correlation.png", dpi=200)

end = time.time()
print(f"\n Time: {end-start}")

# %%
nn_homo = torch.load("nn_gap.pt_full", weights_only=False)

# %%
# Total number of parameters
total_params = sum(p.numel() for p in nn_homo.parameters())
print(f"Total parameters: {total_params:,}")
# Out:
# Total parameters: 2,311,490
